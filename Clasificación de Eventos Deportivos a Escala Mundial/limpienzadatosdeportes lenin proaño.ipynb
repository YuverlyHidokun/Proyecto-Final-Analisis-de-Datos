# %%
import pandas as pd
import mysql.connector

# Configuración de la conexión a MySQL
host = 'localhost'
puerto = 3306
usuario = 'root'
contrasena = '123456'
base_de_datos = 'csv_db 7'

# Crear conexión a la base de datos
conexion = mysql.connector.connect(
    host=host,
    port=puerto,
    user=usuario,
    password=contrasena,
    database=base_de_datos
)

# Query para obtener datos de la base de datos
consulta_sql = "SELECT * FROM toughestsport"

# Leer datos desde MySQL usando pandas
datos = pd.read_sql_query(consulta_sql, conexion)

# Guardar los datos en un archivo CSV
ruta_del_archivo_csv = 'datasetdeportes1.csv'
datos.to_csv(ruta_del_archivo_csv, index=False)
# Cerrar la conexión
conexion.close()

b1 = pd.read_csv("datasetdeportes1.csv")
b1
# Out:
# C:\Users\ignne\AppData\Local\Temp\ipykernel_25572\2291603808.py:24: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   datos = pd.read_sql_query(consulta_sql, conexion)
#          COL 1 COL 2 COL 3 COL 4 COL 5 COL 6 COL 7 COL 8 COL 9 COL 10 COL 11  \
# 0        SPORT   END   STR   PWR   SPD   AGI   FLX   NER   DUR    HAN    ANA
# 1       Boxing  8,63  8,13  8,63  6,38  6,25  4,38  8,88   8,5      7   5,63
# 2   Ice Hockey  7,25  7,13  7,88  7,75  7,63  4,88     6  8,25    7,5    7,5
# 3     Football  5,38  8,63  8,13  7,13  6,38  4,38  7,25   8,5    5,5   7,13
# 4   Basketball  7,38  6,25   6,5  7,25  8,13  5,63  4,13  7,75    7,5   7,38
# ..         ...   ...   ...   ...   ...   ...   ...   ...   ...    ...    ...
# 56     Curling  2,25  2,63   2,5   1,5  2,25  2,63  1,75   1,5   4,88   5,63
# ...

# %%
# Tratamiento de columnas vacías
datos_sin_columnas_vacias = b1.dropna(axis=1)
# Tratamiento de valores nulos
datos_sin_nulos = b1.dropna()
b1
# Out:
#          COL 1 COL 2 COL 3 COL 4 COL 5 COL 6 COL 7 COL 8 COL 9 COL 10 COL 11  \
# 0        SPORT   END   STR   PWR   SPD   AGI   FLX   NER   DUR    HAN    ANA
# 1       Boxing  8,63  8,13  8,63  6,38  6,25  4,38  8,88   8,5      7   5,63
# 2   Ice Hockey  7,25  7,13  7,88  7,75  7,63  4,88     6  8,25    7,5    7,5
# 3     Football  5,38  8,63  8,13  7,13  6,38  4,38  7,25   8,5    5,5   7,13
# 4   Basketball  7,38  6,25   6,5  7,25  8,13  5,63  4,13  7,75    7,5   7,38
# ..         ...   ...   ...   ...   ...   ...   ...   ...   ...    ...    ...
# 56     Curling  2,25  2,63   2,5   1,5  2,25  2,63  1,75   1,5   4,88   5,63
# 57     Bowling  2,25  2,75  3,38     1  1,88  2,38  1,63  1,25   4,75   4,13
# 58    Shooting  2,25   2,5  1,38  0,88  1,13  1,75  2,38  1,88   6,75      4
# 59   Billiards     1     1  1,75  0,75     1  2,63  1,63  0,75   5,25   5,75
# 60     Fishing  1,38  1,63  1,25  0,63   1,5  1,13  0,88  0,88   2,38   2,88
#
#     COL 12 COL 13
# 0    TOTAL   RANK
# ...

# %%
import pandas as pd
import mysql.connector

# Configuración de la conexión a MySQL
host = 'localhost'
puerto = 3306
usuario = 'root'
contrasena = '123456'
base_de_datos = 'csv_db 8'

# Crear conexión a la base de datos
conexion = mysql.connector.connect(
    host=host,
    port=puerto,
    user=usuario,
    password=contrasena,
    database=base_de_datos
)

# Query para obtener datos de la base de datos
consulta_sql = "SELECT * FROM most_values_sports_team"

# Leer datos desde MySQL usando pandas
datos = pd.read_sql_query(consulta_sql, conexion)

# Guardar los datos en un archivo CSV
ruta_del_archivo_csv = 'datasetdeportes2.csv'
datos.to_csv(ruta_del_archivo_csv, index=False)
# Cerrar la conexión
conexion.close()

b2 = pd.read_csv("datasetdeportes2.csv")
b2
# Out:
# C:\Users\ignne\AppData\Local\Temp\ipykernel_25572\3558085059.py:24: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   datos = pd.read_sql_query(consulta_sql, conexion)
#     COL 1                            COL 2          COL 3  \
# 0     NaN                      Sports Team          Value
# 1     0.0             Dallas Cowboys (NFL)   $5.7 billion
# 2     1.0           New York Yankees (MLB)  $5.25 billion
# 3     2.0            New York Knicks (NBA)     $5 billion
# 4     3.0               Barcelona (Soccer)  $4.76 billion
# 5     4.0             Real Madrid (Soccer)  $4.75 billion
# 6     5.0      Golden State Warriors (NBA)   $4.7 billion
# 7     6.0         Los Angeles Lakers (NBA)   $4.6 billion
# 8     7.0       New England Patriots (NFL)   $4.4 billion
# 9     8.0            New York Giants (NFL)   $4.3 billion
# ...

# %%
# Tratamiento de columnas vacías
datos_sin_columnas_vacias = b2.dropna(axis=1)
# Tratamiento de valores nulos
datos_sin_nulos = b2.dropna()
b2
# Out:
#     Unnamed: 0  COL 1                            COL 2          COL 3  \
# 0            0    NaN                      Sports Team          Value
# 1            1    0.0             Dallas Cowboys (NFL)   $5.7 billion
# 2            2    1.0           New York Yankees (MLB)  $5.25 billion
# 3            3    2.0            New York Knicks (NBA)     $5 billion
# 4            4    3.0               Barcelona (Soccer)  $4.76 billion
# 5            5    4.0             Real Madrid (Soccer)  $4.75 billion
# 6            6    5.0      Golden State Warriors (NBA)   $4.7 billion
# 7            7    6.0         Los Angeles Lakers (NBA)   $4.6 billion
# 8            8    7.0       New England Patriots (NFL)   $4.4 billion
# 9            9    8.0            New York Giants (NFL)   $4.3 billion
# 10          10    9.0           Bayern Munich (Soccer)  $4.21 billion
# 11          11   10.0       Manchester United (Soccer)   $4.2 billion
# ...
